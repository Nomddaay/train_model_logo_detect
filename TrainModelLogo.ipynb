# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()

# %%
# !yolo predict model=/content/runs/detect/train/weights/best.pt source='/content/test14.png'
# Out:
# Ultralytics YOLOv8.0.116 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients
#
# image 1/1 /content/test14.png: 384x640 1 Vinh University, 1 Bach Khoa DN University, 122.8ms
# Speed: 3.0ms preprocess, 122.8ms inference, 25.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
# !unrar x /content/coco128.rar

# %%
# !yolo train model=yolov8n.pt data=/content/coco128.yaml epochs=300 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 76.9MB/s]
# Ultralytics YOLOv8.0.116 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load an official model
model = YOLO('/content/runs/detect/train/weights/best.pt')  # load a custom trained

# Export the model
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.116 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients
#
# PyTorch: starting from /content/runs/detect/train/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (6.0 MB)
# requirements: Ultralytics requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 239.0 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ONNX: export success ✅ 7.6s, saved as /content/runs/detect/train/weights/best.onnx (11.7 MB)
#
# Export complete (8.3s)
# Results saved to /content/runs/detect/train/weights
# ...
